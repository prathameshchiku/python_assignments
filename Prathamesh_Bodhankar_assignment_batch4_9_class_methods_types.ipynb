# %% [markdown]
# ## Q1: Create a class called Student
#
# Requirements:
# - Class variable: `school_name = "ABC International School"`
# - Constructor: takes `name` and `marks`
# - Instance method: `display_details()`
# - Class method: `change_school()`
# - Static method: `is_pass(marks)` returns "Pass" if marks ≥ 35 else "Fail"

# %%
class Student:
    school_name = "Gyan Mata Vidya Vihar Sr. Sec. School"
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks

    def display_details(self):
        print(f"Student name : {self.name} | Marks : {self.marks}")
        print(Student.school_name)

    @classmethod
    def change_school(cls,new_school_name):
        cls.school_name = new_school_name

    @staticmethod
    def is_pass(marks):
        if marks>= 35:
            print("Passed!!")
        else:
            print("Failed")

s1 = Student("Prathamesh",99).display_details()   
s2 = Student.change_school("Poodar International") 
s3 = Student.is_pass(99)   
print
# Out:
# Student name : Prathamesh | Marks : 99
# Gyan Mata Vidya Vihar Sr. Sec. School
# Passed!!
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %% [markdown]
# ## Q2: Create a class Calculator
#
# Requirements:
# - Class variable: `count_operations = 0`
# - Instance method: `add(a, b)`
# - Class method: `increment_count()`
# - Static method: `info()`

# %%
class calculator:
    count_operations = 0

    def addd(self,a,b):
        print(a + b)
        calculator.increment_count()

    @classmethod
    def increment_count(cls):
        cls.count_operations += 1

    @staticmethod
    def info():
        print(calculator.count_operations)

s1 = calculator().addd(23,26)        
s2 = calculator().info()
# Out:
# 49
# 1

# %% [markdown]
# ## Q3: Write a class BankAccount
#
# Requirements:
# - Class variable: `bank_name = "SBI"`
# - Constructor: `name`, `balance`
# - Instance method: `deposit(amount)`
# - Class method: `change_bank(new_name)`
# - Static method: `validate_amount(amount)`

# %%
class BankAccount:
    bank_name = "SBI"
    y = 0

    def __init__ (self,name,balance):
        self.name = name
        self.balance = balance
    
    def deposit(self,amount):
        x = BankAccount.validate_amount()
        if x == 1:
            self.balance += amount
        elif x == 0:
            amount += int(input("Enter amount to add : "))
            BankAccount.deposit(self,amount)
        print(self.balance)

    @classmethod
    def change_bank(cls,new_bank_name):
        cls.bank_name = new_bank_name

    @staticmethod
    def validate_amount():
        x = int(input("Enter 1 for validating amount and 0 for adding more cash : "))
        return x
    
s1 = BankAccount("Prathamesh",20000).deposit(5000)
# Out:
# 25000
