# %% [markdown]
# # Pandas Assignment: 50 Basic Questions
#
# Dataset Columns: CID, TID, Gender, Age Group, Purchase Date, Product Category, Discount Availed, Discount Name, Discount Amount (INR), Gross Amount, Net Amount, Purchase Method, Location

# %% [markdown]
# ### 1. Load the CSV file into a Pandas DataFrame.

# %%
import pandas as pd
df = pd.read_csv('C:/Users/Vader/Downloads/csv.csv')

# %% [markdown]
# ### 2. Display the first 5 rows.

# %%
df.head()
# Out:
#    CID   TID  Gender Age Group Purchase Date Product Category  \
# 0  1.0  1001    Male     26-35    15-01-2023      Electronics
# 1  2.0  1002  Female     18-25    10-02-2023         Clothing
# 2  3.0  1003    Male     36-45    05-03-2023       Home Decor
# 3  4.0  1004  Female     26-35    20-01-2023      Electronics
# 4  5.0  1005    Male     18-25    12-04-2023            Books
#
#   Discount Availed         Discount Name  Discount Amount (INR)  Gross Amount  \
# 0              Yes  " Welcome50        "                   1000         12000
# 1              Yes           Summer Sale                    600          3000
# 2               No                   NaN                      0          4500
# 3              Yes        Diwali Dhamaka                   2000         25000
# 4               No                   NaN                      0           800
#
#    Net Amount Purchase Method   Location
# 0       11000     Credit Card     Mumbai
# 1        2400             UPI       Pune
# 2        4500      Debit Card      Delhi
# 3       23000     Credit Card     Mumbai
# 4         800            Cash  Bangalore

# %% [markdown]
# ### 3. Display the last 5 rows.

# %%
df.tail()
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
#
#    Discount Availed   Discount Name  Discount Amount (INR)  Gross Amount  \
# 10               No             NaN                      0          1200
# 11              Yes  Gandhi Jayanti                    800          5500
# 12              Yes      " Diwali "                   1200          4000
# 13              Yes       Christmas                    400          1500
# 14               No             NaN                      0          3500
#
#     Net Amount Purchase Method   Location
# 10        1200            Cash       Pune
# 11        4700     Credit Card     Mumbai
# 12        2800             UPI  Bangalore
# 13        1100            Cash    Chennai
# 14        3500      Debit Card       Pune

# %% [markdown]
# ### 4. Print the shape of the DataFrame.

# %%
df.shape
# Out:
# (15, 13)

# %% [markdown]
# ### 5. Show all column names.

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %% [markdown]
# ### 6. Display the data types of each column.

# %%
df.dtypes
# Out:
# CID                      float64
# TID                        int64
# Gender                    object
# Age Group                 object
# Purchase Date             object
# Product Category          object
# Discount Availed          object
# Discount Name             object
# Discount Amount (INR)      int64
# Gross Amount               int64
# Net Amount                 int64
# Purchase Method           object
# Location                  object
# dtype: object

# %% [markdown]
# ### 7. Check for missing values in each column.

# %%
df.isnull().sum()
# Out:
# CID                      1
# TID                      0
# Gender                   0
# Age Group                0
# Purchase Date            0
# Product Category         0
# Discount Availed         0
# Discount Name            5
# Discount Amount (INR)    0
# Gross Amount             0
# Net Amount               0
# Purchase Method          0
# Location                 0
# dtype: int64

# %% [markdown]
# ### 8. Count total missing values in the dataset.

# %%
df.isnull().sum().sum()
# Out:
# 6

# %% [markdown]
# ### 9. Show summary statistics for numeric columns.

# %%
df.describe()
# Out:
#            CID          TID  Discount Amount (INR)  Gross Amount    Net Amount
# count  14.0000    15.000000              15.000000     15.000000     15.000000
# mean    7.5000  1007.066667             920.000000   9500.000000   8580.000000
# std     4.1833     4.366539            1288.520747  15338.047929  14113.377646
# min     1.0000  1001.000000               0.000000    800.000000    800.000000
# 25%     4.2500  1003.500000               0.000000   1750.000000   1600.000000
# 50%     7.5000  1007.000000             600.000000   4000.000000   3500.000000
# 75%    10.7500  1010.500000            1100.000000   9000.000000   7850.000000
# max    14.0000  1014.000000            5000.000000  60000.000000  55000.000000

# %% [markdown]
# ### 10. Display info about the DataFrame using .info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    14 non-null     float64
#  1   TID                    15 non-null     int64
#  2   Gender                 15 non-null     object
#  3   Age Group              15 non-null     object
#  4   Purchase Date          15 non-null     object
#  5   Product Category       15 non-null     object
#  6   Discount Availed       15 non-null     object
#  7   Discount Name          10 non-null     object
#  8   Discount Amount (INR)  15 non-null     int64
#  9   Gross Amount           15 non-null     int64
#  10  Net Amount             15 non-null     int64
#  11  Purchase Method        15 non-null     object
#  12  Location               15 non-null     object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.6+ KB

# %% [markdown]
# ### 11. Select the CID and TID columns.

# %%
df[['CID','TID']]
# Out:
#      CID   TID
# 0    1.0  1001
# 1    2.0  1002
# 2    3.0  1003
# 3    4.0  1004
# 4    5.0  1005
# 5    6.0  1006
# 6    7.0  1007
# 7    8.0  1008
# 8    9.0  1009
# 9   10.0  1001
# 10  11.0  1010
# 11  12.0  1011
# 12  13.0  1012
# 13  14.0  1013
# 14   NaN  1014

# %% [markdown]
# ### 12. Display the first 10 rows of Gender and Age Group.

# %%
df[['Age Group','Gender']].head(10)
# Out:
#   Age Group  Gender
# 0     26-35    Male
# 1     18-25  Female
# 2     36-45    Male
# 3     26-35  Female
# 4     18-25    Male
# 5     46-55  Female
# 6     26-35    Male
# 7     26-35  Female
# 8       55+    Male
# 9     26-35    Male

# %% [markdown]
# ### 13. Filter rows where Gender is 'Male'.

# %%
df[df['Gender']=='M']
# Out:
# Empty DataFrame
# Columns: [CID, TID, Gender, Age Group, Purchase Date, Product Category, Discount Availed, Discount Name, Discount Amount (INR), Gross Amount, Net Amount, Purchase Method, Location]
# Index: []

# %% [markdown]
# ### 14. Filter rows where Age Group is '26-35'.

# %%
df[df['Age Group'] == '26-35']
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 9               Yes         " Welcome50 "                   1000
# 12              Yes            " Diwali "                   1200
#
#     Gross Amount  Net Amount Purchase Method   Location
# 0          12000       11000     Credit Card     Mumbai
# 3          25000       23000     Credit Card     Mumbai
# 6           2000        1700             UPI    Chennai
# 7           1500        1500     Credit Card     Mumbai
# 9          12000       11000     Credit Card     Mumbai
# 12          4000        2800             UPI  Bangalore

# %% [markdown]
# ### 15. Filter rows where Discount Availed is 'Yes'.

# %%
df[df['Discount Availed'] == 'Yes']
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
#
#     Gross Amount  Net Amount Purchase Method   Location
# 0          12000       11000     Credit Card     Mumbai
# 1           3000        2400             UPI       Pune
# 3          25000       23000     Credit Card     Mumbai
# 5           6000        4500     Credit Card     Mumbai
# 6           2000        1700             UPI    Chennai
# 8          60000       55000     Net Banking      Delhi
# 9          12000       11000     Credit Card     Mumbai
# 11          5500        4700     Credit Card     Mumbai
# 12          4000        2800             UPI  Bangalore
# 13          1500        1100            Cash    Chennai

# %% [markdown]
# ### 16. Filter rows where Discount Amount (INR) > 500.

# %%
df[df['Discount Amount (INR)']>500]
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
#
#     Gross Amount  Net Amount Purchase Method   Location
# 0          12000       11000     Credit Card     Mumbai
# 1           3000        2400             UPI       Pune
# 3          25000       23000     Credit Card     Mumbai
# 5           6000        4500     Credit Card     Mumbai
# 8          60000       55000     Net Banking      Delhi
# 9          12000       11000     Credit Card     Mumbai
# 11          5500        4700     Credit Card     Mumbai
# 12          4000        2800             UPI  Bangalore

# %% [markdown]
# ### 17. Filter rows where Product Category is 'Electronics'.

# %%
df[df['Product Category'] == 'Electronics']
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
#
#     Gross Amount  Net Amount Purchase Method Location
# 0          12000       11000     Credit Card   Mumbai
# 3          25000       23000     Credit Card   Mumbai
# 5           6000        4500     Credit Card   Mumbai
# 8          60000       55000     Net Banking    Delhi
# 9          12000       11000     Credit Card   Mumbai
# 11          5500        4700     Credit Card   Mumbai

# %% [markdown]
# ### 18. Display rows where Purchase Method is 'Credit Card'.

# %%
df[df['Purchase Method'] == 'Credit Card']
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 7                No                   NaN                      0
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
#
#     Gross Amount  Net Amount Purchase Method Location
# 0          12000       11000     Credit Card   Mumbai
# 3          25000       23000     Credit Card   Mumbai
# 5           6000        4500     Credit Card   Mumbai
# 7           1500        1500     Credit Card   Mumbai
# 9          12000       11000     Credit Card   Mumbai
# 11          5500        4700     Credit Card   Mumbai

# %% [markdown]
# ### 19. Select rows where Location is 'Mumbai'.

# %%
df[df['Location'] == 'Mumbai']
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 7                No                   NaN                      0
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
#
#     Gross Amount  Net Amount Purchase Method Location
# 0          12000       11000     Credit Card   Mumbai
# 3          25000       23000     Credit Card   Mumbai
# 5           6000        4500     Credit Card   Mumbai
# 7           1500        1500     Credit Card   Mumbai
# 9          12000       11000     Credit Card   Mumbai
# 11          5500        4700     Credit Card   Mumbai

# %% [markdown]
# ### 20. Select rows where Gross Amount is between 1000 and 5000.

# %%
df[(df['Gross Amount'] > 1000) & (df['Gross Amount'] < 5000)]
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
#
#    Discount Availed Discount Name  Discount Amount (INR)  Gross Amount  \
# 1               Yes   Summer Sale                    600          3000
# 2                No           NaN                      0          4500
# 6               Yes       Flat 50                    300          2000
# 7                No           NaN                      0          1500
# 10               No           NaN                      0          1200
# 12              Yes    " Diwali "                   1200          4000
# 13              Yes     Christmas                    400          1500
# 14               No           NaN                      0          3500
#
#     Net Amount Purchase Method   Location
# 1         2400             UPI       Pune
# 2         4500      Debit Card      Delhi
# 6         1700             UPI    Chennai
# 7         1500     Credit Card     Mumbai
# 10        1200            Cash       Pune
# 12        2800             UPI  Bangalore
# 13        1100            Cash    Chennai
# 14        3500      Debit Card       Pune

# %% [markdown]
# ### 21. Sort the DataFrame by Gross Amount ascending.

# %%
df.sort_values(by='Gross Amount', ascending=True)
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 4    5.0  1005    Male     18-25    12-04-2023            Books
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 4                No                   NaN                      0
# 10               No                   NaN                      0
# 7                No                   NaN                      0
# 13              Yes             Christmas                    400
# 6               Yes               Flat 50                    300
# 1               Yes           Summer Sale                    600
# 14               No                   NaN                      0
# 12              Yes            " Diwali "                   1200
# 2                No                   NaN                      0
# 11              Yes        Gandhi Jayanti                    800
# 5               Yes           " Monsoon "                   1500
# 0               Yes  " Welcome50        "                   1000
# 9               Yes         " Welcome50 "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 8               Yes          Freedom Sale                   5000
#
#     Gross Amount  Net Amount Purchase Method   Location
# 4            800         800            Cash  Bangalore
# 10          1200        1200            Cash       Pune
# 7           1500        1500     Credit Card     Mumbai
# 13          1500        1100            Cash    Chennai
# 6           2000        1700             UPI    Chennai
# 1           3000        2400             UPI       Pune
# 14          3500        3500      Debit Card       Pune
# 12          4000        2800             UPI  Bangalore
# 2           4500        4500      Debit Card      Delhi
# 11          5500        4700     Credit Card     Mumbai
# 5           6000        4500     Credit Card     Mumbai
# 0          12000       11000     Credit Card     Mumbai
# 9          12000       11000     Credit Card     Mumbai
# 3          25000       23000     Credit Card     Mumbai
# 8          60000       55000     Net Banking      Delhi

# %% [markdown]
# ### 22. Sort the DataFrame by Net Amount descending.

# %%
df.sort_values(by='Net Amount', ascending=False)
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 4    5.0  1005    Male     18-25    12-04-2023            Books
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 8               Yes          Freedom Sale                   5000
# 3               Yes        Diwali Dhamaka                   2000
# 0               Yes  " Welcome50        "                   1000
# 9               Yes         " Welcome50 "                   1000
# 11              Yes        Gandhi Jayanti                    800
# 2                No                   NaN                      0
# 5               Yes           " Monsoon "                   1500
# 14               No                   NaN                      0
# 12              Yes            " Diwali "                   1200
# 1               Yes           Summer Sale                    600
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 10               No                   NaN                      0
# 13              Yes             Christmas                    400
# 4                No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location
# 8          60000       55000     Net Banking      Delhi
# 3          25000       23000     Credit Card     Mumbai
# 0          12000       11000     Credit Card     Mumbai
# 9          12000       11000     Credit Card     Mumbai
# 11          5500        4700     Credit Card     Mumbai
# 2           4500        4500      Debit Card      Delhi
# 5           6000        4500     Credit Card     Mumbai
# 14          3500        3500      Debit Card       Pune
# 12          4000        2800             UPI  Bangalore
# 1           3000        2400             UPI       Pune
# 6           2000        1700             UPI    Chennai
# 7           1500        1500     Credit Card     Mumbai
# 10          1200        1200            Cash       Pune
# 13          1500        1100            Cash    Chennai
# 4            800         800            Cash  Bangalore

# %% [markdown]
# ### 23. Sort by Location and then by Purchase Date.

# %%
df.sort_values(by=['Location','Purchase Date'])
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 4    5.0  1005    Male     18-25    12-04-2023            Books
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 4                No                   NaN                      0
# 12              Yes            " Diwali "                   1200
# 6               Yes               Flat 50                    300
# 13              Yes             Christmas                    400
# 2                No                   NaN                      0
# 8               Yes          Freedom Sale                   5000
# 11              Yes        Gandhi Jayanti                    800
# 7                No                   NaN                      0
# 0               Yes  " Welcome50        "                   1000
# 9               Yes         " Welcome50 "                   1000
# 3               Yes        Diwali Dhamaka                   2000
# 5               Yes           " Monsoon "                   1500
# 14               No                   NaN                      0
# 1               Yes           Summer Sale                    600
# 10               No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location
# 4            800         800            Cash  Bangalore
# 12          4000        2800             UPI  Bangalore
# 6           2000        1700             UPI    Chennai
# 13          1500        1100            Cash    Chennai
# 2           4500        4500      Debit Card      Delhi
# 8          60000       55000     Net Banking      Delhi
# 11          5500        4700     Credit Card     Mumbai
# 7           1500        1500     Credit Card     Mumbai
# 0          12000       11000     Credit Card     Mumbai
# 9          12000       11000     Credit Card     Mumbai
# 3          25000       23000     Credit Card     Mumbai
# 5           6000        4500     Credit Card     Mumbai
# 14          3500        3500      Debit Card       Pune
# 1           3000        2400             UPI       Pune
# 10          1200        1200            Cash       Pune

# %% [markdown]
# ### 24. Find the number of unique locations.

# %%
df['Location'].nunique()
# Out:
# 5

# %% [markdown]
# ### 25. Display all unique locations.

# %%
df['Location'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Delhi', 'Bangalore', 'Chennai'], dtype=object)

# %% [markdown]
# ### 26. Find the number of unique product categories.

# %%
df['Product Category'].nunique()
# Out:
# 7

# %% [markdown]
# ### 27. Display the top 10 most frequent product categories.

# %%
df['Product Category'].value_counts().head(10)
# Out:
# Product Category
# Electronics    6
# Clothing       3
# Home Decor     2
# Books          1
# Beauty         1
# Groceries      1
# Toys           1
# Name: count, dtype: int64

# %% [markdown]
# ### 28. Display the top 10 most frequent locations.

# %%
df['Location'].value_counts().head(10)
# Out:
# Location
# Mumbai       6
# Pune         3
# Delhi        2
# Bangalore    2
# Chennai      2
# Name: count, dtype: int64

# %% [markdown]
# ### 29. Find the transaction with the highest Gross Amount.

# %%
df[df['Gross Amount'] == df['Gross Amount'].max()]
# Out:
#    CID   TID Gender Age Group Purchase Date Product Category Discount Availed  \
# 8  9.0  1009   Male       55+    22-08-2023      Electronics              Yes
#
#   Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 8  Freedom Sale                   5000         60000       55000
#
#   Purchase Method Location
# 8     Net Banking    Delhi

# %% [markdown]
# ### 30. Find the transaction with the highest Discount Amount (INR).

# %%
df[df['Discount Amount (INR)'] == df['Discount Amount (INR)'].max()]
# Out:
#    CID   TID Gender Age Group Purchase Date Product Category Discount Availed  \
# 8  9.0  1009   Male       55+    22-08-2023      Electronics              Yes
#
#   Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 8  Freedom Sale                   5000         60000       55000
#
#   Purchase Method Location
# 8     Net Banking    Delhi

# %% [markdown]
# ### 31. Create a new column Discount Percentage = (Discount Amount / Gross Amount) * 100.

# %%
df['Discount Percentage'] = (df['Discount Amount (INR)'] / df['Gross Amount']) * 100
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 4    5.0  1005    Male     18-25    12-04-2023            Books
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 2                No                   NaN                      0
# 3               Yes        Diwali Dhamaka                   2000
# 4                No                   NaN                      0
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 10               No                   NaN                      0
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
# 14               No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location  Discount Percentage
# 0          12000       11000     Credit Card     Mumbai             8.333333
# 1           3000        2400             UPI       Pune            20.000000
# 2           4500        4500      Debit Card      Delhi             0.000000
# 3          25000       23000     Credit Card     Mumbai             8.000000
# 4            800         800            Cash  Bangalore             0.000000
# 5           6000        4500     Credit Card     Mumbai            25.000000
# 6           2000        1700             UPI    Chennai            15.000000
# 7           1500        1500     Credit Card     Mumbai             0.000000
# 8          60000       55000     Net Banking      Delhi             8.333333
# 9          12000       11000     Credit Card     Mumbai             8.333333
# 10          1200        1200            Cash       Pune             0.000000
# 11          5500        4700     Credit Card     Mumbai            14.545455
# 12          4000        2800             UPI  Bangalore            30.000000
# 13          1500        1100            Cash    Chennai            26.666667
# 14          3500        3500      Debit Card       Pune             0.000000

# %% [markdown]
# ### 32. Round Discount Percentage to 2 decimal places.

# %%
df['Discount Percentage'] = df['Discount Percentage'].round(2)
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      Electronics
# 1    2.0  1002  Female     18-25    10-02-2023         Clothing
# 2    3.0  1003    Male     36-45    05-03-2023       Home Decor
# 3    4.0  1004  Female     26-35    20-01-2023      Electronics
# 4    5.0  1005    Male     18-25    12-04-2023            Books
# 5    6.0  1006  Female     46-55    30-05-2023      Electronics
# 6    7.0  1007    Male     26-35    15-06-2023         Clothing
# 7    8.0  1008  Female     26-35    08-07-2023           Beauty
# 8    9.0  1009    Male       55+    22-08-2023      Electronics
# 9   10.0  1001    Male     26-35    15-01-2023      Electronics
# 10  11.0  1010  Female     18-25    10-09-2023        Groceries
# 11  12.0  1011    Male     36-45    02-10-2023      Electronics
# 12  13.0  1012  Female     26-35    14-11-2023         Clothing
# 13  14.0  1013    Male     18-25    25-12-2023             Toys
# 14   NaN  1014  Female     46-55    05-01-2023       Home Decor
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 2                No                   NaN                      0
# 3               Yes        Diwali Dhamaka                   2000
# 4                No                   NaN                      0
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 10               No                   NaN                      0
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
# 14               No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location  Discount Percentage
# 0          12000       11000     Credit Card     Mumbai                 8.33
# 1           3000        2400             UPI       Pune                20.00
# 2           4500        4500      Debit Card      Delhi                 0.00
# 3          25000       23000     Credit Card     Mumbai                 8.00
# 4            800         800            Cash  Bangalore                 0.00
# 5           6000        4500     Credit Card     Mumbai                25.00
# 6           2000        1700             UPI    Chennai                15.00
# 7           1500        1500     Credit Card     Mumbai                 0.00
# 8          60000       55000     Net Banking      Delhi                 8.33
# 9          12000       11000     Credit Card     Mumbai                 8.33
# 10          1200        1200            Cash       Pune                 0.00
# 11          5500        4700     Credit Card     Mumbai                14.55
# 12          4000        2800             UPI  Bangalore                30.00
# 13          1500        1100            Cash    Chennai                26.67
# 14          3500        3500      Debit Card       Pune                 0.00

# %% [markdown]
# ### 33. Convert Product Category to uppercase.

# %%
df['Product Category'] = df['Product Category'].str.upper()
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 2                No                   NaN                      0
# 3               Yes        Diwali Dhamaka                   2000
# 4                No                   NaN                      0
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 10               No                   NaN                      0
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
# 14               No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location  Discount Percentage
# 0          12000       11000     Credit Card     Mumbai                 8.33
# 1           3000        2400             UPI       Pune                20.00
# 2           4500        4500      Debit Card      Delhi                 0.00
# 3          25000       23000     Credit Card     Mumbai                 8.00
# 4            800         800            Cash  Bangalore                 0.00
# 5           6000        4500     Credit Card     Mumbai                25.00
# 6           2000        1700             UPI    Chennai                15.00
# 7           1500        1500     Credit Card     Mumbai                 0.00
# 8          60000       55000     Net Banking      Delhi                 8.33
# 9          12000       11000     Credit Card     Mumbai                 8.33
# 10          1200        1200            Cash       Pune                 0.00
# 11          5500        4700     Credit Card     Mumbai                14.55
# 12          4000        2800             UPI  Bangalore                30.00
# 13          1500        1100            Cash    Chennai                26.67
# 14          3500        3500      Debit Card       Pune                 0.00

# %% [markdown]
# ### 34. Remove leading/trailing spaces from Discount Name.

# %%
df['Discount Name'] = df['Discount Name'].str.strip()
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 2                No                   NaN                      0
# 3               Yes        Diwali Dhamaka                   2000
# 4                No                   NaN                      0
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 7                No                   NaN                      0
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 10               No                   NaN                      0
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
# 14               No                   NaN                      0
#
#     Gross Amount  Net Amount Purchase Method   Location  Discount Percentage
# 0          12000       11000     Credit Card     Mumbai                 8.33
# 1           3000        2400             UPI       Pune                20.00
# 2           4500        4500      Debit Card      Delhi                 0.00
# 3          25000       23000     Credit Card     Mumbai                 8.00
# 4            800         800            Cash  Bangalore                 0.00
# 5           6000        4500     Credit Card     Mumbai                25.00
# 6           2000        1700             UPI    Chennai                15.00
# 7           1500        1500     Credit Card     Mumbai                 0.00
# 8          60000       55000     Net Banking      Delhi                 8.33
# 9          12000       11000     Credit Card     Mumbai                 8.33
# 10          1200        1200            Cash       Pune                 0.00
# 11          5500        4700     Credit Card     Mumbai                14.55
# 12          4000        2800             UPI  Bangalore                30.00
# 13          1500        1100            Cash    Chennai                26.67
# 14          3500        3500      Debit Card       Pune                 0.00

# %% [markdown]
# ### 35. Replace missing Discount Name with 'No Discount'.

# %%
df['Discount Name'] = df['Discount Name'].fillna('No Discount')
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#    Discount Availed         Discount Name  Discount Amount (INR)  \
# 0               Yes  " Welcome50        "                   1000
# 1               Yes           Summer Sale                    600
# 2                No           No Discount                      0
# 3               Yes        Diwali Dhamaka                   2000
# 4                No           No Discount                      0
# 5               Yes           " Monsoon "                   1500
# 6               Yes               Flat 50                    300
# 7                No           No Discount                      0
# 8               Yes          Freedom Sale                   5000
# 9               Yes         " Welcome50 "                   1000
# 10               No           No Discount                      0
# 11              Yes        Gandhi Jayanti                    800
# 12              Yes            " Diwali "                   1200
# 13              Yes             Christmas                    400
# 14               No           No Discount                      0
#
#     Gross Amount  Net Amount Purchase Method   Location  Discount Percentage
# 0          12000       11000     Credit Card     Mumbai                 8.33
# 1           3000        2400             UPI       Pune                20.00
# 2           4500        4500      Debit Card      Delhi                 0.00
# 3          25000       23000     Credit Card     Mumbai                 8.00
# 4            800         800            Cash  Bangalore                 0.00
# 5           6000        4500     Credit Card     Mumbai                25.00
# 6           2000        1700             UPI    Chennai                15.00
# 7           1500        1500     Credit Card     Mumbai                 0.00
# 8          60000       55000     Net Banking      Delhi                 8.33
# 9          12000       11000     Credit Card     Mumbai                 8.33
# 10          1200        1200            Cash       Pune                 0.00
# 11          5500        4700     Credit Card     Mumbai                14.55
# 12          4000        2800             UPI  Bangalore                30.00
# 13          1500        1100            Cash    Chennai                26.67
# 14          3500        3500      Debit Card       Pune                 0.00

# %% [markdown]
# ### 36. Drop the Discount Availed column.

# %%
df.drop('Discount Availed', axis=1, inplace=True)
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                   1000         12000       11000
# 1            Summer Sale                    600          3000        2400
# 2            No Discount                      0          4500        4500
# 3         Diwali Dhamaka                   2000         25000       23000
# 4            No Discount                      0           800         800
# 5            " Monsoon "                   1500          6000        4500
# 6                Flat 50                    300          2000        1700
# 7            No Discount                      0          1500        1500
# 8           Freedom Sale                   5000         60000       55000
# 9          " Welcome50 "                   1000         12000       11000
# 10           No Discount                      0          1200        1200
# 11        Gandhi Jayanti                    800          5500        4700
# 12            " Diwali "                   1200          4000        2800
# 13             Christmas                    400          1500        1100
# 14           No Discount                      0          3500        3500
#
#    Purchase Method   Location  Discount Percentage
# 0      Credit Card     Mumbai                 8.33
# 1              UPI       Pune                20.00
# 2       Debit Card      Delhi                 0.00
# 3      Credit Card     Mumbai                 8.00
# 4             Cash  Bangalore                 0.00
# 5      Credit Card     Mumbai                25.00
# 6              UPI    Chennai                15.00
# 7      Credit Card     Mumbai                 0.00
# 8      Net Banking      Delhi                 8.33
# 9      Credit Card     Mumbai                 8.33
# 10            Cash       Pune                 0.00
# 11     Credit Card     Mumbai                14.55
# 12             UPI  Bangalore                30.00
# 13            Cash    Chennai                26.67
# 14      Debit Card       Pune                 0.00

# %% [markdown]
# ### 37. Rename Purchase Method column to PaymentMethod.

# %%
df.rename(columns={'Purchase Method': 'PaymentMethod'}, inplace=True)
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                   1000         12000       11000
# 1            Summer Sale                    600          3000        2400
# 2            No Discount                      0          4500        4500
# 3         Diwali Dhamaka                   2000         25000       23000
# 4            No Discount                      0           800         800
# 5            " Monsoon "                   1500          6000        4500
# 6                Flat 50                    300          2000        1700
# 7            No Discount                      0          1500        1500
# 8           Freedom Sale                   5000         60000       55000
# 9          " Welcome50 "                   1000         12000       11000
# 10           No Discount                      0          1200        1200
# 11        Gandhi Jayanti                    800          5500        4700
# 12            " Diwali "                   1200          4000        2800
# 13             Christmas                    400          1500        1100
# 14           No Discount                      0          3500        3500
#
#    PaymentMethod   Location  Discount Percentage
# 0    Credit Card     Mumbai                 8.33
# 1            UPI       Pune                20.00
# 2     Debit Card      Delhi                 0.00
# 3    Credit Card     Mumbai                 8.00
# 4           Cash  Bangalore                 0.00
# 5    Credit Card     Mumbai                25.00
# 6            UPI    Chennai                15.00
# 7    Credit Card     Mumbai                 0.00
# 8    Net Banking      Delhi                 8.33
# 9    Credit Card     Mumbai                 8.33
# 10          Cash       Pune                 0.00
# 11   Credit Card     Mumbai                14.55
# 12           UPI  Bangalore                30.00
# 13          Cash    Chennai                26.67
# 14    Debit Card       Pune                 0.00

# %% [markdown]
# ### 38. Reorder columns so CID and TID come first.

# %%
cols = ['CID', 'TID'] + [col for col in df.columns if col not in ['CID', 'TID']]
df = df[cols]
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 9   10.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                   1000         12000       11000
# 1            Summer Sale                    600          3000        2400
# 2            No Discount                      0          4500        4500
# 3         Diwali Dhamaka                   2000         25000       23000
# 4            No Discount                      0           800         800
# 5            " Monsoon "                   1500          6000        4500
# 6                Flat 50                    300          2000        1700
# 7            No Discount                      0          1500        1500
# 8           Freedom Sale                   5000         60000       55000
# 9          " Welcome50 "                   1000         12000       11000
# 10           No Discount                      0          1200        1200
# 11        Gandhi Jayanti                    800          5500        4700
# 12            " Diwali "                   1200          4000        2800
# 13             Christmas                    400          1500        1100
# 14           No Discount                      0          3500        3500
#
#    PaymentMethod   Location  Discount Percentage
# 0    Credit Card     Mumbai                 8.33
# 1            UPI       Pune                20.00
# 2     Debit Card      Delhi                 0.00
# 3    Credit Card     Mumbai                 8.00
# 4           Cash  Bangalore                 0.00
# 5    Credit Card     Mumbai                25.00
# 6            UPI    Chennai                15.00
# 7    Credit Card     Mumbai                 0.00
# 8    Net Banking      Delhi                 8.33
# 9    Credit Card     Mumbai                 8.33
# 10          Cash       Pune                 0.00
# 11   Credit Card     Mumbai                14.55
# 12           UPI  Bangalore                30.00
# 13          Cash    Chennai                26.67
# 14    Debit Card       Pune                 0.00

# %% [markdown]
# ### 39. Check if TID column has duplicates.

# %%
df['TID'].is_unique
# Out:
# False

# %% [markdown]
# ### 40. Drop duplicate rows based on TID.

# %%
df.drop_duplicates(subset=['TID'], keep='first', inplace=True)
df
# Out:
#      CID   TID  Gender Age Group Purchase Date Product Category  \
# 0    1.0  1001    Male     26-35    15-01-2023      ELECTRONICS
# 1    2.0  1002  Female     18-25    10-02-2023         CLOTHING
# 2    3.0  1003    Male     36-45    05-03-2023       HOME DECOR
# 3    4.0  1004  Female     26-35    20-01-2023      ELECTRONICS
# 4    5.0  1005    Male     18-25    12-04-2023            BOOKS
# 5    6.0  1006  Female     46-55    30-05-2023      ELECTRONICS
# 6    7.0  1007    Male     26-35    15-06-2023         CLOTHING
# 7    8.0  1008  Female     26-35    08-07-2023           BEAUTY
# 8    9.0  1009    Male       55+    22-08-2023      ELECTRONICS
# 10  11.0  1010  Female     18-25    10-09-2023        GROCERIES
# 11  12.0  1011    Male     36-45    02-10-2023      ELECTRONICS
# 12  13.0  1012  Female     26-35    14-11-2023         CLOTHING
# 13  14.0  1013    Male     18-25    25-12-2023             TOYS
# 14   NaN  1014  Female     46-55    05-01-2023       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                   1000         12000       11000
# 1            Summer Sale                    600          3000        2400
# 2            No Discount                      0          4500        4500
# 3         Diwali Dhamaka                   2000         25000       23000
# 4            No Discount                      0           800         800
# 5            " Monsoon "                   1500          6000        4500
# 6                Flat 50                    300          2000        1700
# 7            No Discount                      0          1500        1500
# 8           Freedom Sale                   5000         60000       55000
# 10           No Discount                      0          1200        1200
# 11        Gandhi Jayanti                    800          5500        4700
# 12            " Diwali "                   1200          4000        2800
# 13             Christmas                    400          1500        1100
# 14           No Discount                      0          3500        3500
#
#    PaymentMethod   Location  Discount Percentage
# 0    Credit Card     Mumbai                 8.33
# 1            UPI       Pune                20.00
# 2     Debit Card      Delhi                 0.00
# 3    Credit Card     Mumbai                 8.00
# 4           Cash  Bangalore                 0.00
# 5    Credit Card     Mumbai                25.00
# 6            UPI    Chennai                15.00
# 7    Credit Card     Mumbai                 0.00
# 8    Net Banking      Delhi                 8.33
# 10          Cash       Pune                 0.00
# 11   Credit Card     Mumbai                14.55
# 12           UPI  Bangalore                30.00
# 13          Cash    Chennai                26.67
# 14    Debit Card       Pune                 0.00

# %% [markdown]
# ### 41. Convert Purchase Date to datetime format.

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
df.dtypes
# Out:
# C:\Users\Vader\AppData\Local\Temp\ipykernel_13340\1489001083.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
# CID                             float64
# TID                               int64
# Gender                           object
# Age Group                        object
# Purchase Date            datetime64[ns]
# Product Category                 object
# Discount Name                    object
# Discount Amount (INR)             int64
# Gross Amount                      int64
# Net Amount                        int64
# PaymentMethod                    object
# Location                         object
# Discount Percentage             float64
# dtype: object

# %% [markdown]
# ### 42. Convert CID to integer type (handle missing values first).

# %%
df['CID'] = df['CID'].fillna(0)

df['CID'] = df['CID'].astype(int)
df.dtypes
# Out:
# CID                               int32
# TID                               int64
# Gender                           object
# Age Group                        object
# Purchase Date            datetime64[ns]
# Product Category                 object
# Discount Name                    object
# Discount Amount (INR)             int64
# Gross Amount                      int64
# Net Amount                        int64
# PaymentMethod                    object
# Location                         object
# Discount Percentage             float64
# dtype: object

# %% [markdown]
# ### 43. Convert Discount Amount (INR) to float type.

# %%
df['Discount Amount (INR)'] = df['Discount Amount (INR)'].astype(float)
df.dtypes
df
# Out:
#     CID   TID  Gender Age Group Purchase Date Product Category  \
# 0     1  1001    Male     26-35    2023-01-15      ELECTRONICS
# 1     2  1002  Female     18-25    2023-02-10         CLOTHING
# 2     3  1003    Male     36-45    2023-03-05       HOME DECOR
# 3     4  1004  Female     26-35    2023-01-20      ELECTRONICS
# 4     5  1005    Male     18-25    2023-04-12            BOOKS
# 5     6  1006  Female     46-55    2023-05-30      ELECTRONICS
# 6     7  1007    Male     26-35    2023-06-15         CLOTHING
# 7     8  1008  Female     26-35    2023-07-08           BEAUTY
# 8     9  1009    Male       55+    2023-08-22      ELECTRONICS
# 10   11  1010  Female     18-25    2023-09-10        GROCERIES
# 11   12  1011    Male     36-45    2023-10-02      ELECTRONICS
# 12   13  1012  Female     26-35    2023-11-14         CLOTHING
# 13   14  1013    Male     18-25    2023-12-25             TOYS
# 14    0  1014  Female     46-55    2023-01-05       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                 1000.0         12000       11000
# 1            Summer Sale                  600.0          3000        2400
# 2            No Discount                    0.0          4500        4500
# 3         Diwali Dhamaka                 2000.0         25000       23000
# 4            No Discount                    0.0           800         800
# 5            " Monsoon "                 1500.0          6000        4500
# 6                Flat 50                  300.0          2000        1700
# 7            No Discount                    0.0          1500        1500
# 8           Freedom Sale                 5000.0         60000       55000
# 10           No Discount                    0.0          1200        1200
# 11        Gandhi Jayanti                  800.0          5500        4700
# 12            " Diwali "                 1200.0          4000        2800
# 13             Christmas                  400.0          1500        1100
# 14           No Discount                    0.0          3500        3500
#
#    PaymentMethod   Location  Discount Percentage
# 0    Credit Card     Mumbai                 8.33
# 1            UPI       Pune                20.00
# 2     Debit Card      Delhi                 0.00
# 3    Credit Card     Mumbai                 8.00
# 4           Cash  Bangalore                 0.00
# 5    Credit Card     Mumbai                25.00
# 6            UPI    Chennai                15.00
# 7    Credit Card     Mumbai                 0.00
# 8    Net Banking      Delhi                 8.33
# 10          Cash       Pune                 0.00
# 11   Credit Card     Mumbai                14.55
# 12           UPI  Bangalore                30.00
# 13          Cash    Chennai                26.67
# 14    Debit Card       Pune                 0.00

# %% [markdown]
# ### 44. Convert Gross Amount and Net Amount to float type.

# %%
df[['Gross Amount','Net Amount']] = df[['Gross Amount','Net Amount']].astype(float)
df.dtypes
df
# Out:
#     CID   TID  Gender Age Group Purchase Date Product Category  \
# 0     1  1001    Male     26-35    2023-01-15      ELECTRONICS
# 1     2  1002  Female     18-25    2023-02-10         CLOTHING
# 2     3  1003    Male     36-45    2023-03-05       HOME DECOR
# 3     4  1004  Female     26-35    2023-01-20      ELECTRONICS
# 4     5  1005    Male     18-25    2023-04-12            BOOKS
# 5     6  1006  Female     46-55    2023-05-30      ELECTRONICS
# 6     7  1007    Male     26-35    2023-06-15         CLOTHING
# 7     8  1008  Female     26-35    2023-07-08           BEAUTY
# 8     9  1009    Male       55+    2023-08-22      ELECTRONICS
# 10   11  1010  Female     18-25    2023-09-10        GROCERIES
# 11   12  1011    Male     36-45    2023-10-02      ELECTRONICS
# 12   13  1012  Female     26-35    2023-11-14         CLOTHING
# 13   14  1013    Male     18-25    2023-12-25             TOYS
# 14    0  1014  Female     46-55    2023-01-05       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                 1000.0       12000.0     11000.0
# 1            Summer Sale                  600.0        3000.0      2400.0
# 2            No Discount                    0.0        4500.0      4500.0
# 3         Diwali Dhamaka                 2000.0       25000.0     23000.0
# 4            No Discount                    0.0         800.0       800.0
# 5            " Monsoon "                 1500.0        6000.0      4500.0
# 6                Flat 50                  300.0        2000.0      1700.0
# 7            No Discount                    0.0        1500.0      1500.0
# 8           Freedom Sale                 5000.0       60000.0     55000.0
# 10           No Discount                    0.0        1200.0      1200.0
# 11        Gandhi Jayanti                  800.0        5500.0      4700.0
# 12            " Diwali "                 1200.0        4000.0      2800.0
# 13             Christmas                  400.0        1500.0      1100.0
# 14           No Discount                    0.0        3500.0      3500.0
#
#    PaymentMethod   Location  Discount Percentage
# 0    Credit Card     Mumbai                 8.33
# 1            UPI       Pune                20.00
# 2     Debit Card      Delhi                 0.00
# 3    Credit Card     Mumbai                 8.00
# 4           Cash  Bangalore                 0.00
# 5    Credit Card     Mumbai                25.00
# 6            UPI    Chennai                15.00
# 7    Credit Card     Mumbai                 0.00
# 8    Net Banking      Delhi                 8.33
# 10          Cash       Pune                 0.00
# 11   Credit Card     Mumbai                14.55
# 12           UPI  Bangalore                30.00
# 13          Cash    Chennai                26.67
# 14    Debit Card       Pune                 0.00

# %%
print("Memory Before (bytes):")
print(df[['Gender', 'Location']].memory_usage(deep=True))
# Out:
# Memory Before (bytes):
# Index       112
# Gender      868
# Location    882
# dtype: int64

# %% [markdown]
# ### 45. Convert Gender column to category type.

# %%
df['Gender'] = df['Gender'].astype('category')
df.dtypes
# Out:
# CID                               int32
# TID                               int64
# Gender                         category
# Age Group                        object
# Purchase Date            datetime64[ns]
# Product Category                 object
# Discount Name                    object
# Discount Amount (INR)           float64
# Gross Amount                    float64
# Net Amount                      float64
# PaymentMethod                    object
# Location                         object
# Discount Percentage             float64
# dtype: object

# %% [markdown]
# ### 46. Convert Location column to category type.

# %%
df['Location'] = df['Location'].astype('category')
df.dtypes
# Out:
# CID                               int32
# TID                               int64
# Gender                         category
# Age Group                        object
# Purchase Date            datetime64[ns]
# Product Category                 object
# Discount Name                    object
# Discount Amount (INR)           float64
# Gross Amount                    float64
# Net Amount                      float64
# PaymentMethod                    object
# Location                       category
# Discount Percentage             float64
# dtype: object

# %% [markdown]
# ### 47. Check memory usage before and after converting categorical columns.

# %%
print("\nMemory After (bytes):")
print(df[['Gender', 'Location']].memory_usage(deep=True))
# Out:
# Memory After (bytes):
# Index       112
# Gender      246
# Location    502
# dtype: int64

# %% [markdown]
# ### 48. Extract the year from Purchase Date into a new column.

# %%
df['Purchase Year'] = df['Purchase Date'].dt.year
df
# Out:
#     CID   TID  Gender Age Group Purchase Date Product Category  \
# 0     1  1001    Male     26-35    2023-01-15      ELECTRONICS
# 1     2  1002  Female     18-25    2023-02-10         CLOTHING
# 2     3  1003    Male     36-45    2023-03-05       HOME DECOR
# 3     4  1004  Female     26-35    2023-01-20      ELECTRONICS
# 4     5  1005    Male     18-25    2023-04-12            BOOKS
# 5     6  1006  Female     46-55    2023-05-30      ELECTRONICS
# 6     7  1007    Male     26-35    2023-06-15         CLOTHING
# 7     8  1008  Female     26-35    2023-07-08           BEAUTY
# 8     9  1009    Male       55+    2023-08-22      ELECTRONICS
# 10   11  1010  Female     18-25    2023-09-10        GROCERIES
# 11   12  1011    Male     36-45    2023-10-02      ELECTRONICS
# 12   13  1012  Female     26-35    2023-11-14         CLOTHING
# 13   14  1013    Male     18-25    2023-12-25             TOYS
# 14    0  1014  Female     46-55    2023-01-05       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                 1000.0       12000.0     11000.0
# 1            Summer Sale                  600.0        3000.0      2400.0
# 2            No Discount                    0.0        4500.0      4500.0
# 3         Diwali Dhamaka                 2000.0       25000.0     23000.0
# 4            No Discount                    0.0         800.0       800.0
# 5            " Monsoon "                 1500.0        6000.0      4500.0
# 6                Flat 50                  300.0        2000.0      1700.0
# 7            No Discount                    0.0        1500.0      1500.0
# 8           Freedom Sale                 5000.0       60000.0     55000.0
# 10           No Discount                    0.0        1200.0      1200.0
# 11        Gandhi Jayanti                  800.0        5500.0      4700.0
# 12            " Diwali "                 1200.0        4000.0      2800.0
# 13             Christmas                  400.0        1500.0      1100.0
# 14           No Discount                    0.0        3500.0      3500.0
#
#    PaymentMethod   Location  Discount Percentage  Purchase Year
# 0    Credit Card     Mumbai                 8.33           2023
# 1            UPI       Pune                20.00           2023
# 2     Debit Card      Delhi                 0.00           2023
# 3    Credit Card     Mumbai                 8.00           2023
# 4           Cash  Bangalore                 0.00           2023
# 5    Credit Card     Mumbai                25.00           2023
# 6            UPI    Chennai                15.00           2023
# 7    Credit Card     Mumbai                 0.00           2023
# 8    Net Banking      Delhi                 8.33           2023
# 10          Cash       Pune                 0.00           2023
# 11   Credit Card     Mumbai                14.55           2023
# 12           UPI  Bangalore                30.00           2023
# 13          Cash    Chennai                26.67           2023
# 14    Debit Card       Pune                 0.00           2023

# %% [markdown]
# ### 49. Extract the month from Purchase Date into a new column.

# %%
df['Purchase month'] = df['Purchase Date'].dt.month
df
# Out:
#     CID   TID  Gender Age Group Purchase Date Product Category  \
# 0     1  1001    Male     26-35    2023-01-15      ELECTRONICS
# 1     2  1002  Female     18-25    2023-02-10         CLOTHING
# 2     3  1003    Male     36-45    2023-03-05       HOME DECOR
# 3     4  1004  Female     26-35    2023-01-20      ELECTRONICS
# 4     5  1005    Male     18-25    2023-04-12            BOOKS
# 5     6  1006  Female     46-55    2023-05-30      ELECTRONICS
# 6     7  1007    Male     26-35    2023-06-15         CLOTHING
# 7     8  1008  Female     26-35    2023-07-08           BEAUTY
# 8     9  1009    Male       55+    2023-08-22      ELECTRONICS
# 10   11  1010  Female     18-25    2023-09-10        GROCERIES
# 11   12  1011    Male     36-45    2023-10-02      ELECTRONICS
# 12   13  1012  Female     26-35    2023-11-14         CLOTHING
# 13   14  1013    Male     18-25    2023-12-25             TOYS
# 14    0  1014  Female     46-55    2023-01-05       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                 1000.0       12000.0     11000.0
# 1            Summer Sale                  600.0        3000.0      2400.0
# 2            No Discount                    0.0        4500.0      4500.0
# 3         Diwali Dhamaka                 2000.0       25000.0     23000.0
# 4            No Discount                    0.0         800.0       800.0
# 5            " Monsoon "                 1500.0        6000.0      4500.0
# 6                Flat 50                  300.0        2000.0      1700.0
# 7            No Discount                    0.0        1500.0      1500.0
# 8           Freedom Sale                 5000.0       60000.0     55000.0
# 10           No Discount                    0.0        1200.0      1200.0
# 11        Gandhi Jayanti                  800.0        5500.0      4700.0
# 12            " Diwali "                 1200.0        4000.0      2800.0
# 13             Christmas                  400.0        1500.0      1100.0
# 14           No Discount                    0.0        3500.0      3500.0
#
#    PaymentMethod   Location  Discount Percentage  Purchase Year  \
# 0    Credit Card     Mumbai                 8.33           2023
# 1            UPI       Pune                20.00           2023
# 2     Debit Card      Delhi                 0.00           2023
# 3    Credit Card     Mumbai                 8.00           2023
# 4           Cash  Bangalore                 0.00           2023
# 5    Credit Card     Mumbai                25.00           2023
# 6            UPI    Chennai                15.00           2023
# 7    Credit Card     Mumbai                 0.00           2023
# 8    Net Banking      Delhi                 8.33           2023
# 10          Cash       Pune                 0.00           2023
# 11   Credit Card     Mumbai                14.55           2023
# 12           UPI  Bangalore                30.00           2023
# 13          Cash    Chennai                26.67           2023
# 14    Debit Card       Pune                 0.00           2023
#
#     Purchase month
# 0                1
# 1                2
# 2                3
# 3                1
# 4                4
# 5                5
# 6                6
# 7                7
# 8                8
# 10               9
# 11              10
# 12              11
# 13              12
# 14               1

# %% [markdown]
# ### 50. Extract the day name from Purchase Date into a new column.

# %%
df['Day Name'] = df['Purchase Date'].dt.day_name()
df
# Out:
#     CID   TID  Gender Age Group Purchase Date Product Category  \
# 0     1  1001    Male     26-35    2023-01-15      ELECTRONICS
# 1     2  1002  Female     18-25    2023-02-10         CLOTHING
# 2     3  1003    Male     36-45    2023-03-05       HOME DECOR
# 3     4  1004  Female     26-35    2023-01-20      ELECTRONICS
# 4     5  1005    Male     18-25    2023-04-12            BOOKS
# 5     6  1006  Female     46-55    2023-05-30      ELECTRONICS
# 6     7  1007    Male     26-35    2023-06-15         CLOTHING
# 7     8  1008  Female     26-35    2023-07-08           BEAUTY
# 8     9  1009    Male       55+    2023-08-22      ELECTRONICS
# 10   11  1010  Female     18-25    2023-09-10        GROCERIES
# 11   12  1011    Male     36-45    2023-10-02      ELECTRONICS
# 12   13  1012  Female     26-35    2023-11-14         CLOTHING
# 13   14  1013    Male     18-25    2023-12-25             TOYS
# 14    0  1014  Female     46-55    2023-01-05       HOME DECOR
#
#            Discount Name  Discount Amount (INR)  Gross Amount  Net Amount  \
# 0   " Welcome50        "                 1000.0       12000.0     11000.0
# 1            Summer Sale                  600.0        3000.0      2400.0
# 2            No Discount                    0.0        4500.0      4500.0
# 3         Diwali Dhamaka                 2000.0       25000.0     23000.0
# 4            No Discount                    0.0         800.0       800.0
# 5            " Monsoon "                 1500.0        6000.0      4500.0
# 6                Flat 50                  300.0        2000.0      1700.0
# 7            No Discount                    0.0        1500.0      1500.0
# 8           Freedom Sale                 5000.0       60000.0     55000.0
# 10           No Discount                    0.0        1200.0      1200.0
# 11        Gandhi Jayanti                  800.0        5500.0      4700.0
# 12            " Diwali "                 1200.0        4000.0      2800.0
# 13             Christmas                  400.0        1500.0      1100.0
# 14           No Discount                    0.0        3500.0      3500.0
#
#    PaymentMethod   Location  Discount Percentage  Purchase Year  \
# 0    Credit Card     Mumbai                 8.33           2023
# 1            UPI       Pune                20.00           2023
# 2     Debit Card      Delhi                 0.00           2023
# 3    Credit Card     Mumbai                 8.00           2023
# 4           Cash  Bangalore                 0.00           2023
# 5    Credit Card     Mumbai                25.00           2023
# 6            UPI    Chennai                15.00           2023
# 7    Credit Card     Mumbai                 0.00           2023
# 8    Net Banking      Delhi                 8.33           2023
# 10          Cash       Pune                 0.00           2023
# 11   Credit Card     Mumbai                14.55           2023
# 12           UPI  Bangalore                30.00           2023
# 13          Cash    Chennai                26.67           2023
# 14    Debit Card       Pune                 0.00           2023
#
#     Purchase month   Day Name
# 0                1     Sunday
# 1                2     Friday
# 2                3     Sunday
# 3                1     Friday
# 4                4  Wednesday
# 5                5    Tuesday
# 6                6   Thursday
# 7                7   Saturday
# 8                8    Tuesday
# 10               9     Sunday
# 11              10     Monday
# 12              11    Tuesday
# 13              12     Monday
# 14               1   Thursday
